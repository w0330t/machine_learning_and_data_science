# %% [markdown]
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
# %%
# 欢迎来到你的第三周编程作业。
# 你已经准备好构建一个双层的神经网络，训练它以解决分类问题。
# %%
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation
# %%
# - 实现一个用于解决分类问题的双层神经网络。
# - 实现矩阵乘法的前向传播
# - 执行反向传播
# %%

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
# %%
# 在本周的第一个实验中，你训练了一个仅含单个感知机的神经网络，并且运行了前向和后向传播。
# 那个简单的结构足以解决一个“线性”分类问题——在平面上找到一个条线，用这条线作为区分两个类别的决策边界。
# %%
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.
# %%
# 设想现在你面临一个更复杂的问题：你仍然有两个类别，但仅用一条线已不足以将它们分开。
# %%

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
# %%
# 这种逻辑可能会出现在很多应用中出现。
# 举一个例子，如果你训练一个模型，根据房屋的面积和建造年份来预测是否应该购买。
# 一个新的大房子你可能无法负担，但是一个小的旧房子又不值得购买。
# 所以你可能对一个旧的大房子感兴趣，或者是一个新的小房子。
# %%
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
# %%
# 仅含有一个感知机的神经网络不能解决这样的分类问题。
# 让我们看看你如何调整这个模型找到这个答案。
# %%
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
# %%
# 在上面的绘图中，两根线可以作为其决策边界。
# 你的直觉可能告诉你应该增加感知机的数量来解决这个问题。
# 这绝对是明智的选择！
# 你需要将你的数据点（坐标 $x_{1},x_{2}$）分别输入两个节点中，然后将它们统一起来，以便做出决定。
# %%
# Now let's figure out the details, build and train your first multi-layer neural network!
# %%
# 现在我们来详细探讨一下，构建和训练你的第一个多层神经网络！
# %%

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
# %%
# 这个神经网络的输入和输出层和单个感知机模型是一样的，但是这里有一个**隐藏层**夹在它们的中间。
# 来自形状为 $n_x = 2$ 输入层的训练样本 $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ 首先被送入大小为 $n_h = 2$ 的隐藏层。
# 它们同时被送入两个感知机，第一个感知机的权重为 $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$，偏置为 $b_1^{[1]}$；第二个感知机的权重为 $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$，偏置为 $b_2^{[1]}$。
# 右上角的反括号中的数字 $^{[1]}$ 表示层号，因为这里有两层，它们分别都有自己的参数和输出需要加以区分。
# %%
#
# $$
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
# $$
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
# %%
# 这个表达式可以将训练样本 $x^{(i)}$ 重写成一个矩阵：
# %%
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# -  $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# - $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} = \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# -  $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.
# %%
# 其中
# - $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ 是一个尺寸为 $\left(n_h \times 1\right) = \left(2 \times 1\right)$ 的向量；
# - $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} = \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ 是一个尺寸为 $\left(n_h \times n_x\right) = \left(2 \times 2\right)$ 的矩阵；
# -  $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ 是一个尺寸为 $\left(n_h \times 1\right) = \left(2 \times 1\right)$ 的向量。
# %%
#
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
# %%
# 下一步，隐藏层里的激活函数需要应用在向量 $z^{[1](i)}$ 的每个元素中。
# 各种激活函数都可以应用在这里，但在模型中采用了 sigmoid 函数 $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$。
# 记住它的导数是 $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$。
# 隐藏层输出的向量形状是 $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
# %%
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
# %%
# 隐藏层输出的值形状为 $n_y = 1$，它会进入输出层。
# 这在上一个实验中已经讨论过了，这里唯一的不同是 $a^{[1](i)}$ 替代了 $x^{(i)}$，并且使用了层标记 $^{[2]}$ 来表示所有的参数和输出值：
# %%
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
#
# -  $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# -  $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# %%
# 其中
# -  $z^{[2](i)}$ 和 $b^{[2]}$ 是这个模型的标量, 形状为 $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
# -  $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ 是向量，形状为 $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
# %%
#
# Finally, the same sigmoid function is used as the output layer activation function:
# %%
# 最后，同样采用 sigmoid 函数作为输出层的激活函数：
# %%
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
# %%
# 在数学上，双层的神经网络模型每个训练样本 $x^{(i)}$ 都可以写作表达式 $(2) - (5)$。
# 为了方便起见，让我们把它们写在一起。
# %%
# $$
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \end{align}
# \tag{6}
# $$
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.
#
# %%
# 注意，模型中所有待训练的参数均不带 $^{(i)}$ 索引，这意味着它们独立于输入数据。
# %%
#
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.
# %%
# 最后，对于样本 $x^{(i)}$ 的预测，可以通过输出 $a^{[2](i)}$ 并计算 $\hat{y}$ 来完成。
# %%

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
# %%
# 类似单感知机模型，$m$ 个训练样本可以组织成一个形状为 $(2 × m)$ 的矩阵 $X$，将 $x^{(i)}$ 放入这个矩阵的列中。
# 然后式子（6）可以用矩阵乘法的形式进行重写：
# %%
# $$
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \end{align}
# \tag{7}
# $$
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
# %%
# 其中 $b^{[1]}$ 会被广播为矩阵，其形状为 $\left(n_h \times m\right) = \left(2 \times m\right)$，同样的 $b^{[2]}$ 会变为向量，其形状为 $\left(n_y \times m\right) = \left(1 \times m\right)$。
# 仔细观察这些表达式 $(7)$，然后检查检查矩阵的形状是否匹配以执行所需的乘法运算。
# %%
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.
#
# %%
# 你已经推导出前向传播的表达式，是时候评估你的模型并且训练它了。
# %%

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
# %%
# 评估这个简单的神经网络，你同样可以使用单感知机的成本函数——对数损失函数。
# 最初的权重仅仅是一些随机值，现在你需要开始训练模型，寻找一组适合的参数 $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$，以最小化这个成本函数。
# %%
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
# %%
# 就像上一个单感知机神经网络的例子那样，这个成本函数可以写作：
# %%
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
# %%
# 其中 $y^{(i)} \in \{0,1\}$ 是原始的标签，而 $a^{[2](i)}$ 是是前向传播的连续输出值。（数组 $A^{[2]}$ 的元素）。
# %%
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
# %%
# 要对它最小化，你可以使用梯度下降，像下面表达式那样更新参数：
# %%
# $$
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \end{align}
# \tag{9}
# $$
# where $\alpha$ is the learning rate.
# %%
# 其中 $\alpha$ 是学习率
# %%
#
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
# %%
# 要训练这个模型你现在需要计算 $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$、 $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$、$\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$ 和 $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$。
# %%
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
# %%
# 让我们从这个神经网络的末端开始。
# 你可以在这里写下 $\frac{\partial \mathcal{L} }{ \partial W }$ 和 $\frac{\partial \mathcal{L} }{ \partial b }$ 单感知机神经网络对应的表达式。
# %%
#
# $$\begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
# $$
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
# %%
# 其中 $1$ 只是一个形状为 ($m \times 1$) 的全一向量。
# 你的单感知机现在在第二层，所以 $W$ 将替换为 $W^{[2]}$， $b$ 替换为 $b^{[2]}$， $A$ 替换为 $A^{[2]}$，$X$ 替换为 $A^{[1]}$:
# %%
# $$
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \end{align}
# \tag{10}
# $$
#
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\\frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that
#
# %%
# 现在让我们找到 $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ 对应的矩阵。
# 之前在视频中也说过。
# %%
#
# $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
# %%
# 如果你想要计算矩阵 $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ 每个元素的准确值，那么你将得到这个矩阵：
# %%
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$
#
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
# %%
# 你能注意到所有项和指数都是一致的，所以它们可以统一成一个矩阵形式。
# 形状为 $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ 的 $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ 可以和形状为 $\left(n_y \times m\right) = \left(1 \times m\right)$ 的向量 $A^{[2]} - Y$ 相乘，得到形状为 $\left(n_h \times m\right) = \left(2 \times m\right)$ 的矩阵。
# %%
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
# %%
# 现在来看看相同形状 $\left(n_h \times m\right) = \left(2 \times m\right)$ 的矩阵 $A^{[1]}$
# %%
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
# %%
# 你可以这样计算
# %%
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.
# %%
# 其中"$\cdot$"表示元素与元素相乘
# %%
#
# With the element by element multiplication,
# %%
# 逐个元素相乘
# %%
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
# %%
# 如果你用 $X^T$ （形状为 $\left(m \times n_x\right) = \left(m \times 2\right)$）执行矩阵乘法，你会得到大小为 $\left(n_h \times n_x\right) = \left(2 \times 2\right)$ 的矩阵：
# %%
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
# %%
# 正如表达式 $(12)$ 描述的那样，所以 $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ 可以写作矩阵乘法：
# %%
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.
# %%
# 其中"$\cdot$"还是元素乘以元素
# %%
#
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
# %%
# 向量 $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ 的计算过程非常的相似，但是它在链式法则的最后一项为 1，即 $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$，由此可得：
# %%
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
# %%
# 其中 $1$ 是一个形状为 $m \times 1$ 的全一向量
# %%
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
# %%
# 公式 $(10)$、$(13)$ 和 $(14)$ 算出了梯度，我们需要把这些梯度带入到公式 $(9)$ 中，从而完成反向传播阶段的参数更新。
# %%
# $$
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \end{align}
# \tag{15}
# $$
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
# %%
# 其中 $1$ 还是一个形状为 $m \times 1$ 的全一向量
# %%
#
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
# %%
# 深入且恰当地理解神经网络如何运作与训练，你需要线性代数和微积分的知识进行结合！
# 不必担心，只要按部就班，准确理解数学，整体来看并没那么可怕。
# %%
# Time to implement this all in the code!
# %%
# 是时候去实现所有的代码了！
# %%

# %% [markdown]
# <a name='2.4'></a>
# ### 2.4 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.
# %%
# 首先，我们来获取您将要处理的数据集。
# 下面的代码创建了 $m=2000$ 的数据点，然后将它们保存在这个形状为 $(2 \times m)$，类型为 `NumPy` 数组的变量 `X` 中（$2$ 行 $m$ 列，也就是 2 行 2000 列）。
# 它的标签（0 为蓝色，1 为红色）保存在形状为 $(1 \times m)$，类型为 `NumPy` 数组的变量 `Y` 中（1 行 $m$ 列）。
# %%

# %%
m = 2000
samples, labels = make_blobs(n_samples=m,
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]),
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.5'></a>
# ### 2.5 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# #### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1/(1+np.exp(-z))
    ### END CODE HERE ###

    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# #### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer
#
# %%
# 定义三个变量
# - `n_x`：输入层的形状。
# - `n_h`：隐藏层的形状（暂时将其设为 2）。
# - `n_y`：输出层的形状。
# %%

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)

    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0]
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# #### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.
#
# %%
# - 保证你的参数形状正确。如果需要请参考神经网络计算图。
# - 你需要用随机值初始化权重矩阵；使用 `np.random.randn(a,b) * 0.01` 来对形状为 (a,b) 的矩阵进行随机化。
# - 你需要将偏置初始化为全零的向量；使用 `np.zeros((a,b))` 来对形状为 (a,b) 的矩阵填充 0。
# %%

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer

    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """

    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###

    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}

    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# #### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.
#
#
# %%
# 你需要实现的步骤包括：
# 1. 从字典 "parameters" 取出每个参数。
# 2. 实现前向传播。计算 `Z1`，即矩阵 `W1` 和 `X` 相乘后加上向量 `b1`。然后通过 `sigmoid` 激活函数求得 `A1`。对 `Z2` 和 `A2` 同样进行类似的计算。
# %%

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)

    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###

    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = W1 @ X + b1
    A1 = sigmoid(Z1)
    Z2 = W2 @ A1 + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###

    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}

    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.
#
# %%
# 请记得，你的权重只是一些之前初始化生成的随机值，所以模型尚未开始训练。
# %%

# %% [markdown]
# <a name='ex05'></a>
# #### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss

    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)

    Returns:
    cost -- log loss

    """
    # Number of examples.
    m = Y.shape[1]

    ### START CODE HERE ### (~ 2 lines of code)
    logloss = - Y * np.log(A2) - (1 - Y) * np.log(1 - A2)
    cost = 1 / m * np.sum(logloss)
    ### END CODE HERE ###

    assert(isinstance(cost, float))

    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6931477703826823

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# %%
# 计算式子 $(15)$ 列出的偏导数
# %%
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients

    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)

    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]

    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]

    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]

    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)

    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}

    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-1.49856632e-05  1.67791519e-05]
#  [-2.12394543e-05  2.43895135e-05]]
# db1 = [[5.11207671e-07]
#  [7.06236219e-07]]
# dW2 = [[-0.00032641 -0.0002606 ]]
# db2 = [[-0.00078732]]

# %% [markdown]
# <a name='ex06'></a>
# #### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.
#
# %%
# 实现步骤：
# 1. 从字典 "parameters" 取出每个参数。
# 2. 从字典 “grads” 中获取导数。
# 3. 根据上面的公式更新参数。
# %%

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule

    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent

    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    ### END CODE HERE ###

    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads["dW1"]
    db1 = grads["db1"]
    dW2 = grads["dW2"]
    db2 = grads["db2"]
    ### END CODE HERE ###

    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    ### END CODE HERE ###

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}

    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# #### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.
#
# %%
# 神经网络模型的构建必须按正确顺序调用前面的函数。
# %%

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration

    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """

    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]

    # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###

    # Loop.
    for i in range(0, num_iterations):

        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)

        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)

        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)

        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)
        ### END CODE HERE ###

        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# Cost after iteration 6: 0.693147
# Cost after iteration 7: 0.693147
# Cost after iteration 8: 0.693147
# Cost after iteration 9: 0.693147
# Cost after iteration 10: 0.693147
# Cost after iteration 11: 0.693147
# Cost after iteration 12: 0.693147
# Cost after iteration 13: 0.693147
# Cost after iteration 14: 0.693147
# Cost after iteration 15: 0.693147
# Cost after iteration 16: 0.693147
# Cost after iteration 17: 0.693147
# Cost after iteration 18: 0.693147
# Cost after iteration 19: 0.693147
# Cost after iteration 20: 0.693147
# Cost after iteration 21: 0.693147
# Cost after iteration 22: 0.693146
# Cost after iteration 23: 0.693146
# Cost after iteration 24: 0.693146
# Cost after iteration 25: 0.693146
# Cost after iteration 26: 0.693146
# Cost after iteration 27: 0.693146
# Cost after iteration 28: 0.693146
# Cost after iteration 29: 0.693146
# Cost after iteration 30: 0.693146
# Cost after iteration 31: 0.693146
# Cost after iteration 32: 0.693146
# Cost after iteration 33: 0.693146
# Cost after iteration 34: 0.693146
# Cost after iteration 35: 0.693146
# Cost after iteration 36: 0.693146
# Cost after iteration 37: 0.693146
# Cost after iteration 38: 0.693146
# Cost after iteration 39: 0.693146
# Cost after iteration 40: 0.693146
# Cost after iteration 41: 0.693146
# Cost after iteration 42: 0.693146
# Cost after iteration 43: 0.693146
# Cost after iteration 44: 0.693146
# Cost after iteration 45: 0.693146
# Cost after iteration 46: 0.693146
# Cost after iteration 47: 0.693146
# Cost after iteration 48: 0.693146
# Cost after iteration 49: 0.693146
# Cost after iteration 50: 0.693146
# Cost after iteration 51: 0.693146
# Cost after iteration 52: 0.693146
# Cost after iteration 53: 0.693145
# Cost after iteration 54: 0.693145
# Cost after iteration 55: 0.693145
# Cost after iteration 56: 0.693145
# Cost after iteration 57: 0.693145
# Cost after iteration 58: 0.693145
# Cost after iteration 59: 0.693145
# Cost after iteration 60: 0.693145
# Cost after iteration 61: 0.693145
# Cost after iteration 62: 0.693145
# Cost after iteration 63: 0.693145
# Cost after iteration 64: 0.693145
# Cost after iteration 65: 0.693145
# Cost after iteration 66: 0.693145
# Cost after iteration 67: 0.693145
# Cost after iteration 68: 0.693145
# Cost after iteration 69: 0.693145
# Cost after iteration 70: 0.693145
# Cost after iteration 71: 0.693145
# Cost after iteration 72: 0.693145
# Cost after iteration 73: 0.693144
# Cost after iteration 74: 0.693144
# Cost after iteration 75: 0.693144
# Cost after iteration 76: 0.693144
# Cost after iteration 77: 0.693144
# Cost after iteration 78: 0.693144
# Cost after iteration 79: 0.693144
# Cost after iteration 80: 0.693144
# Cost after iteration 81: 0.693144
# Cost after iteration 82: 0.693144
# Cost after iteration 83: 0.693144
# Cost after iteration 84: 0.693144
# Cost after iteration 85: 0.693144
# Cost after iteration 86: 0.693144
# Cost after iteration 87: 0.693144
# Cost after iteration 88: 0.693143
# Cost after iteration 89: 0.693143
# Cost after iteration 90: 0.693143
# Cost after iteration 91: 0.693143
# Cost after iteration 92: 0.693143
# Cost after iteration 93: 0.693143
# Cost after iteration 94: 0.693143
# Cost after iteration 95: 0.693143
# Cost after iteration 96: 0.693143
# Cost after iteration 97: 0.693143
# Cost after iteration 98: 0.693143
# Cost after iteration 99: 0.693142
# Cost after iteration 100: 0.693142
# Cost after iteration 101: 0.693142
# Cost after iteration 102: 0.693142
# Cost after iteration 103: 0.693142
# Cost after iteration 104: 0.693142
# Cost after iteration 105: 0.693142
# Cost after iteration 106: 0.693142
# Cost after iteration 107: 0.693142
# Cost after iteration 108: 0.693142
# Cost after iteration 109: 0.693141
# Cost after iteration 110: 0.693141
# Cost after iteration 111: 0.693141
# Cost after iteration 112: 0.693141
# Cost after iteration 113: 0.693141
# Cost after iteration 114: 0.693141
# Cost after iteration 115: 0.693141
# Cost after iteration 116: 0.693140
# Cost after iteration 117: 0.693140
# Cost after iteration 118: 0.693140
# Cost after iteration 119: 0.693140
# Cost after iteration 120: 0.693140
# Cost after iteration 121: 0.693140
# Cost after iteration 122: 0.693140
# Cost after iteration 123: 0.693139
# Cost after iteration 124: 0.693139
# Cost after iteration 125: 0.693139
# Cost after iteration 126: 0.693139
# Cost after iteration 127: 0.693139
# Cost after iteration 128: 0.693139
# Cost after iteration 129: 0.693138
# Cost after iteration 130: 0.693138
# Cost after iteration 131: 0.693138
# Cost after iteration 132: 0.693138
# Cost after iteration 133: 0.693138
# Cost after iteration 134: 0.693137
# Cost after iteration 135: 0.693137
# Cost after iteration 136: 0.693137
# Cost after iteration 137: 0.693137
# Cost after iteration 138: 0.693137
# Cost after iteration 139: 0.693136
# Cost after iteration 140: 0.693136
# Cost after iteration 141: 0.693136
# Cost after iteration 142: 0.693136
# Cost after iteration 143: 0.693135
# Cost after iteration 144: 0.693135
# Cost after iteration 145: 0.693135
# Cost after iteration 146: 0.693135
# Cost after iteration 147: 0.693134
# Cost after iteration 148: 0.693134
# Cost after iteration 149: 0.693134
# Cost after iteration 150: 0.693134
# Cost after iteration 151: 0.693133
# Cost after iteration 152: 0.693133
# Cost after iteration 153: 0.693133
# Cost after iteration 154: 0.693132
# Cost after iteration 155: 0.693132
# Cost after iteration 156: 0.693132
# Cost after iteration 157: 0.693131
# Cost after iteration 158: 0.693131
# Cost after iteration 159: 0.693131
# Cost after iteration 160: 0.693130
# Cost after iteration 161: 0.693130
# Cost after iteration 162: 0.693130
# Cost after iteration 163: 0.693129
# Cost after iteration 164: 0.693129
# Cost after iteration 165: 0.693128
# Cost after iteration 166: 0.693128
# Cost after iteration 167: 0.693128
# Cost after iteration 168: 0.693127
# Cost after iteration 169: 0.693127
# Cost after iteration 170: 0.693126
# Cost after iteration 171: 0.693126
# Cost after iteration 172: 0.693125
# Cost after iteration 173: 0.693125
# Cost after iteration 174: 0.693124
# Cost after iteration 175: 0.693124
# Cost after iteration 176: 0.693123
# Cost after iteration 177: 0.693123
# Cost after iteration 178: 0.693122
# Cost after iteration 179: 0.693121
# Cost after iteration 180: 0.693121
# Cost after iteration 181: 0.693120
# Cost after iteration 182: 0.693120
# Cost after iteration 183: 0.693119
# Cost after iteration 184: 0.693118
# Cost after iteration 185: 0.693118
# Cost after iteration 186: 0.693117
# Cost after iteration 187: 0.693116
# Cost after iteration 188: 0.693115
# Cost after iteration 189: 0.693115
# Cost after iteration 190: 0.693114
# Cost after iteration 191: 0.693113
# Cost after iteration 192: 0.693112
# Cost after iteration 193: 0.693111
# Cost after iteration 194: 0.693110
# Cost after iteration 195: 0.693110
# Cost after iteration 196: 0.693109
# Cost after iteration 197: 0.693108
# Cost after iteration 198: 0.693107
# Cost after iteration 199: 0.693106
# Cost after iteration 200: 0.693104
# Cost after iteration 201: 0.693103
# Cost after iteration 202: 0.693102
# Cost after iteration 203: 0.693101
# Cost after iteration 204: 0.693100
# Cost after iteration 205: 0.693098
# Cost after iteration 206: 0.693097
# Cost after iteration 207: 0.693096
# Cost after iteration 208: 0.693094
# Cost after iteration 209: 0.693093
# Cost after iteration 210: 0.693091
# Cost after iteration 211: 0.693089
# Cost after iteration 212: 0.693088
# Cost after iteration 213: 0.693086
# Cost after iteration 214: 0.693084
# Cost after iteration 215: 0.693082
# Cost after iteration 216: 0.693080
# Cost after iteration 217: 0.693078
# Cost after iteration 218: 0.693076
# Cost after iteration 219: 0.693073
# Cost after iteration 220: 0.693071
# Cost after iteration 221: 0.693068
# Cost after iteration 222: 0.693066
# Cost after iteration 223: 0.693063
# Cost after iteration 224: 0.693060
# Cost after iteration 225: 0.693057
# Cost after iteration 226: 0.693053
# Cost after iteration 227: 0.693050
# Cost after iteration 228: 0.693046
# Cost after iteration 229: 0.693042
# Cost after iteration 230: 0.693038
# Cost after iteration 231: 0.693034
# Cost after iteration 232: 0.693029
# Cost after iteration 233: 0.693024
# Cost after iteration 234: 0.693018
# Cost after iteration 235: 0.693013
# Cost after iteration 236: 0.693006
# Cost after iteration 237: 0.693000
# Cost after iteration 238: 0.692993
# Cost after iteration 239: 0.692985
# Cost after iteration 240: 0.692977
# Cost after iteration 241: 0.692968
# Cost after iteration 242: 0.692958
# Cost after iteration 243: 0.692948
# Cost after iteration 244: 0.692936
# Cost after iteration 245: 0.692924
# Cost after iteration 246: 0.692910
# Cost after iteration 247: 0.692896
# Cost after iteration 248: 0.692879
# Cost after iteration 249: 0.692861
# Cost after iteration 250: 0.692841
# Cost after iteration 251: 0.692819
# Cost after iteration 252: 0.692795
# Cost after iteration 253: 0.692768
# Cost after iteration 254: 0.692737
# Cost after iteration 255: 0.692703
# Cost after iteration 256: 0.692664
# Cost after iteration 257: 0.692621
# Cost after iteration 258: 0.692572
# Cost after iteration 259: 0.692516
# Cost after iteration 260: 0.692452
# Cost after iteration 261: 0.692379
# Cost after iteration 262: 0.692294
# Cost after iteration 263: 0.692198
# Cost after iteration 264: 0.692085
# Cost after iteration 265: 0.691955
# Cost after iteration 266: 0.691804
# Cost after iteration 267: 0.691627
# Cost after iteration 268: 0.691420
# Cost after iteration 269: 0.691177
# Cost after iteration 270: 0.690893
# Cost after iteration 271: 0.690559
# Cost after iteration 272: 0.690166
# Cost after iteration 273: 0.689705
# Cost after iteration 274: 0.689165
# Cost after iteration 275: 0.688534
# Cost after iteration 276: 0.687800
# Cost after iteration 277: 0.686949
# Cost after iteration 278: 0.685968
# Cost after iteration 279: 0.684848
# Cost after iteration 280: 0.683576
# Cost after iteration 281: 0.682146
# Cost after iteration 282: 0.680554
# Cost after iteration 283: 0.678799
# Cost after iteration 284: 0.676884
# Cost after iteration 285: 0.674819
# Cost after iteration 286: 0.672613
# Cost after iteration 287: 0.670281
# Cost after iteration 288: 0.667841
# Cost after iteration 289: 0.665312
# Cost after iteration 290: 0.662711
# Cost after iteration 291: 0.660059
# Cost after iteration 292: 0.657374
# Cost after iteration 293: 0.654673
# Cost after iteration 294: 0.651972
# Cost after iteration 295: 0.649284
# Cost after iteration 296: 0.646622
# Cost after iteration 297: 0.643994
# Cost after iteration 298: 0.641409
# Cost after iteration 299: 0.638873
# Cost after iteration 300: 0.636390
# Cost after iteration 301: 0.633963
# Cost after iteration 302: 0.631593
# Cost after iteration 303: 0.629280
# Cost after iteration 304: 0.627023
# Cost after iteration 305: 0.624820
# Cost after iteration 306: 0.622668
# Cost after iteration 307: 0.620561
# Cost after iteration 308: 0.618495
# Cost after iteration 309: 0.616463
# Cost after iteration 310: 0.614459
# Cost after iteration 311: 0.612473
# Cost after iteration 312: 0.610496
# Cost after iteration 313: 0.608516
# Cost after iteration 314: 0.606517
# Cost after iteration 315: 0.604482
# Cost after iteration 316: 0.602387
# Cost after iteration 317: 0.600206
# Cost after iteration 318: 0.597905
# Cost after iteration 319: 0.595447
# Cost after iteration 320: 0.592794
# Cost after iteration 321: 0.589905
# Cost after iteration 322: 0.586741
# Cost after iteration 323: 0.583268
# Cost after iteration 324: 0.579459
# Cost after iteration 325: 0.575296
# Cost after iteration 326: 0.570775
# Cost after iteration 327: 0.565905
# Cost after iteration 328: 0.560704
# Cost after iteration 329: 0.555206
# Cost after iteration 330: 0.549448
# Cost after iteration 331: 0.543474
# Cost after iteration 332: 0.537330
# Cost after iteration 333: 0.531060
# Cost after iteration 334: 0.524707
# Cost after iteration 335: 0.518309
# Cost after iteration 336: 0.511901
# Cost after iteration 337: 0.505512
# Cost after iteration 338: 0.499169
# Cost after iteration 339: 0.492893
# Cost after iteration 340: 0.486702
# Cost after iteration 341: 0.480611
# Cost after iteration 342: 0.474631
# Cost after iteration 343: 0.468771
# Cost after iteration 344: 0.463038
# Cost after iteration 345: 0.457437
# Cost after iteration 346: 0.451972
# Cost after iteration 347: 0.446645
# Cost after iteration 348: 0.441456
# Cost after iteration 349: 0.436406
# Cost after iteration 350: 0.431493
# Cost after iteration 351: 0.426717
# Cost after iteration 352: 0.422076
# Cost after iteration 353: 0.417566
# Cost after iteration 354: 0.413186
# Cost after iteration 355: 0.408933
# Cost after iteration 356: 0.404803
# Cost after iteration 357: 0.400793
# Cost after iteration 358: 0.396900
# Cost after iteration 359: 0.393121
# Cost after iteration 360: 0.389451
# Cost after iteration 361: 0.385889
# Cost after iteration 362: 0.382429
# Cost after iteration 363: 0.379069
# Cost after iteration 364: 0.375806
# Cost after iteration 365: 0.372635
# Cost after iteration 366: 0.369555
# Cost after iteration 367: 0.366561
# Cost after iteration 368: 0.363652
# Cost after iteration 369: 0.360823
# Cost after iteration 370: 0.358072
# Cost after iteration 371: 0.355396
# Cost after iteration 372: 0.352792
# Cost after iteration 373: 0.350259
# Cost after iteration 374: 0.347792
# Cost after iteration 375: 0.345391
# Cost after iteration 376: 0.343052
# Cost after iteration 377: 0.340773
# Cost after iteration 378: 0.338553
# Cost after iteration 379: 0.336388
# Cost after iteration 380: 0.334277
# Cost after iteration 381: 0.332219
# Cost after iteration 382: 0.330210
# Cost after iteration 383: 0.328250
# Cost after iteration 384: 0.326336
# Cost after iteration 385: 0.324467
# Cost after iteration 386: 0.322642
# Cost after iteration 387: 0.320858
# Cost after iteration 388: 0.319114
# Cost after iteration 389: 0.317410
# Cost after iteration 390: 0.315743
# Cost after iteration 391: 0.314112
# Cost after iteration 392: 0.312516
# Cost after iteration 393: 0.310954
# Cost after iteration 394: 0.309424
# Cost after iteration 395: 0.307926
# Cost after iteration 396: 0.306458
# Cost after iteration 397: 0.305020
# Cost after iteration 398: 0.303610
# Cost after iteration 399: 0.302227
# Cost after iteration 400: 0.300871
# Cost after iteration 401: 0.299540
# Cost after iteration 402: 0.298234
# Cost after iteration 403: 0.296951
# Cost after iteration 404: 0.295692
# Cost after iteration 405: 0.294456
# Cost after iteration 406: 0.293240
# Cost after iteration 407: 0.292046
# Cost after iteration 408: 0.290872
# Cost after iteration 409: 0.289718
# Cost after iteration 410: 0.288582
# Cost after iteration 411: 0.287465
# Cost after iteration 412: 0.286366
# Cost after iteration 413: 0.285284
# Cost after iteration 414: 0.284219
# Cost after iteration 415: 0.283170
# Cost after iteration 416: 0.282136
# Cost after iteration 417: 0.281118
# Cost after iteration 418: 0.280114
# Cost after iteration 419: 0.279125
# Cost after iteration 420: 0.278150
# Cost after iteration 421: 0.277188
# Cost after iteration 422: 0.276239
# Cost after iteration 423: 0.275303
# Cost after iteration 424: 0.274379
# Cost after iteration 425: 0.273467
# Cost after iteration 426: 0.272566
# Cost after iteration 427: 0.271677
# Cost after iteration 428: 0.270799
# Cost after iteration 429: 0.269932
# Cost after iteration 430: 0.269075
# Cost after iteration 431: 0.268228
# Cost after iteration 432: 0.267390
# Cost after iteration 433: 0.266563
# Cost after iteration 434: 0.265745
# Cost after iteration 435: 0.264935
# Cost after iteration 436: 0.264135
# Cost after iteration 437: 0.263343
# Cost after iteration 438: 0.262560
# Cost after iteration 439: 0.261784
# Cost after iteration 440: 0.261017
# Cost after iteration 441: 0.260258
# Cost after iteration 442: 0.259506
# Cost after iteration 443: 0.258761
# Cost after iteration 444: 0.258024
# Cost after iteration 445: 0.257294
# Cost after iteration 446: 0.256571
# Cost after iteration 447: 0.255855
# Cost after iteration 448: 0.255145
# Cost after iteration 449: 0.254442
# Cost after iteration 450: 0.253746
# Cost after iteration 451: 0.253055
# Cost after iteration 452: 0.252371
# Cost after iteration 453: 0.251693
# Cost after iteration 454: 0.251021
# Cost after iteration 455: 0.250354
# Cost after iteration 456: 0.249694
# Cost after iteration 457: 0.249039
# Cost after iteration 458: 0.248389
# Cost after iteration 459: 0.247745
# Cost after iteration 460: 0.247107
# Cost after iteration 461: 0.246474
# Cost after iteration 462: 0.245846
# Cost after iteration 463: 0.245223
# Cost after iteration 464: 0.244605
# Cost after iteration 465: 0.243992
# Cost after iteration 466: 0.243385
# Cost after iteration 467: 0.242782
# Cost after iteration 468: 0.242184
# Cost after iteration 469: 0.241591
# Cost after iteration 470: 0.241003
# Cost after iteration 471: 0.240420
# Cost after iteration 472: 0.239841
# Cost after iteration 473: 0.239267
# Cost after iteration 474: 0.238697
# Cost after iteration 475: 0.238133
# Cost after iteration 476: 0.237572
# Cost after iteration 477: 0.237017
# Cost after iteration 478: 0.236466
# Cost after iteration 479: 0.235919
# Cost after iteration 480: 0.235377
# Cost after iteration 481: 0.234839
# Cost after iteration 482: 0.234306
# Cost after iteration 483: 0.233777
# Cost after iteration 484: 0.233252
# Cost after iteration 485: 0.232732
# Cost after iteration 486: 0.232216
# Cost after iteration 487: 0.231705
# Cost after iteration 488: 0.231198
# Cost after iteration 489: 0.230695
# Cost after iteration 490: 0.230197
# Cost after iteration 491: 0.229703
# Cost after iteration 492: 0.229213
# Cost after iteration 493: 0.228727
# Cost after iteration 494: 0.228246
# Cost after iteration 495: 0.227769
# Cost after iteration 496: 0.227296
# Cost after iteration 497: 0.226827
# Cost after iteration 498: 0.226363
# Cost after iteration 499: 0.225903
# Cost after iteration 500: 0.225446
# Cost after iteration 501: 0.224995
# Cost after iteration 502: 0.224547
# Cost after iteration 503: 0.224103
# Cost after iteration 504: 0.223664
# Cost after iteration 505: 0.223228
# Cost after iteration 506: 0.222797
# Cost after iteration 507: 0.222370
# Cost after iteration 508: 0.221947
# Cost after iteration 509: 0.221528
# Cost after iteration 510: 0.221113
# Cost after iteration 511: 0.220702
# Cost after iteration 512: 0.220295
# Cost after iteration 513: 0.219892
# Cost after iteration 514: 0.219493
# Cost after iteration 515: 0.219098
# Cost after iteration 516: 0.218707
# Cost after iteration 517: 0.218320
# Cost after iteration 518: 0.217937
# Cost after iteration 519: 0.217557
# Cost after iteration 520: 0.217182
# Cost after iteration 521: 0.216810
# Cost after iteration 522: 0.216442
# Cost after iteration 523: 0.216078
# Cost after iteration 524: 0.215718
# Cost after iteration 525: 0.215361
# Cost after iteration 526: 0.215008
# Cost after iteration 527: 0.214659
# Cost after iteration 528: 0.214313
# Cost after iteration 529: 0.213971
# Cost after iteration 530: 0.213632
# Cost after iteration 531: 0.213297
# Cost after iteration 532: 0.212966
# Cost after iteration 533: 0.212638
# Cost after iteration 534: 0.212314
# Cost after iteration 535: 0.211993
# Cost after iteration 536: 0.211675
# Cost after iteration 537: 0.211361
# Cost after iteration 538: 0.211050
# Cost after iteration 539: 0.210743
# Cost after iteration 540: 0.210439
# Cost after iteration 541: 0.210138
# Cost after iteration 542: 0.209840
# Cost after iteration 543: 0.209546
# Cost after iteration 544: 0.209256
# Cost after iteration 545: 0.208974
# Cost after iteration 546: 0.208715
# Cost after iteration 547: 0.208540
# Cost after iteration 548: 0.208718
# Cost after iteration 549: 0.210415
# Cost after iteration 550: 0.218887
# Cost after iteration 551: 0.260245
# Cost after iteration 552: 0.462927
# Cost after iteration 553: 0.921669
# Cost after iteration 554: 0.388789
# Cost after iteration 555: 0.579625
# Cost after iteration 556: 0.315857
# Cost after iteration 557: 0.310104
# Cost after iteration 558: 0.248794
# Cost after iteration 559: 0.240407
# Cost after iteration 560: 0.229705
# Cost after iteration 561: 0.225770
# Cost after iteration 562: 0.221545
# Cost after iteration 563: 0.219502
# Cost after iteration 564: 0.217440
# Cost after iteration 565: 0.216221
# Cost after iteration 566: 0.215024
# Cost after iteration 567: 0.214195
# Cost after iteration 568: 0.213385
# Cost after iteration 569: 0.212768
# Cost after iteration 570: 0.212165
# Cost after iteration 571: 0.211689
# Cost after iteration 572: 0.211227
# Cost after iteration 573: 0.210880
# Cost after iteration 574: 0.210558
# Cost after iteration 575: 0.210380
# Cost after iteration 576: 0.210263
# Cost after iteration 577: 0.210394
# Cost after iteration 578: 0.210695
# Cost after iteration 579: 0.211548
# Cost after iteration 580: 0.212907
# Cost after iteration 581: 0.215788
# Cost after iteration 582: 0.220378
# Cost after iteration 583: 0.230004
# Cost after iteration 584: 0.246753
# Cost after iteration 585: 0.280232
# Cost after iteration 586: 0.351591
# Cost after iteration 587: 0.414577
# Cost after iteration 588: 0.484399
# Cost after iteration 589: 0.379339
# Cost after iteration 590: 0.377613
# Cost after iteration 591: 0.295348
# Cost after iteration 592: 0.288205
# Cost after iteration 593: 0.244916
# Cost after iteration 594: 0.245200
# Cost after iteration 595: 0.228540
# Cost after iteration 596: 0.227480
# Cost after iteration 597: 0.221256
# Cost after iteration 598: 0.219949
# Cost after iteration 599: 0.216973
# Cost after iteration 600: 0.215899
# Cost after iteration 601: 0.214246
# Cost after iteration 602: 0.213426
# Cost after iteration 603: 0.212382
# Cost after iteration 604: 0.211739
# Cost after iteration 605: 0.210994
# Cost after iteration 606: 0.210461
# Cost after iteration 607: 0.209873
# Cost after iteration 608: 0.209409
# Cost after iteration 609: 0.208910
# Cost after iteration 610: 0.208494
# Cost after iteration 611: 0.208051
# Cost after iteration 612: 0.207671
# Cost after iteration 613: 0.207269
# Cost after iteration 614: 0.206922
# Cost after iteration 615: 0.206553
# Cost after iteration 616: 0.206240
# Cost after iteration 617: 0.205906
# Cost after iteration 618: 0.205635
# Cost after iteration 619: 0.205341
# Cost after iteration 620: 0.205131
# Cost after iteration 621: 0.204891
# Cost after iteration 622: 0.204779
# Cost after iteration 623: 0.204625
# Cost after iteration 624: 0.204686
# Cost after iteration 625: 0.204679
# Cost after iteration 626: 0.205076
# Cost after iteration 627: 0.205339
# Cost after iteration 628: 0.206443
# Cost after iteration 629: 0.207219
# Cost after iteration 630: 0.209906
# Cost after iteration 631: 0.211604
# Cost after iteration 632: 0.217877
# Cost after iteration 633: 0.220591
# Cost after iteration 634: 0.233923
# Cost after iteration 635: 0.234802
# Cost after iteration 636: 0.257728
# Cost after iteration 637: 0.252440
# Cost after iteration 638: 0.285611
# Cost after iteration 639: 0.288643
# Cost after iteration 640: 0.360273
# Cost after iteration 641: 0.403728
# Cost after iteration 642: 0.512164
# Cost after iteration 643: 0.399918
# Cost after iteration 644: 0.368405
# Cost after iteration 645: 0.276488
# Cost after iteration 646: 0.241601
# Cost after iteration 647: 0.222941
# Cost after iteration 648: 0.217238
# Cost after iteration 649: 0.212793
# Cost after iteration 650: 0.211094
# Cost after iteration 651: 0.209387
# Cost after iteration 652: 0.208444
# Cost after iteration 653: 0.207567
# Cost after iteration 654: 0.206940
# Cost after iteration 655: 0.206359
# Cost after iteration 656: 0.205870
# Cost after iteration 657: 0.205407
# Cost after iteration 658: 0.204984
# Cost after iteration 659: 0.204576
# Cost after iteration 660: 0.204188
# Cost after iteration 661: 0.203810
# Cost after iteration 662: 0.203444
# Cost after iteration 663: 0.203087
# Cost after iteration 664: 0.202739
# Cost after iteration 665: 0.202397
# Cost after iteration 666: 0.202063
# Cost after iteration 667: 0.201734
# Cost after iteration 668: 0.201413
# Cost after iteration 669: 0.201097
# Cost after iteration 670: 0.200787
# Cost after iteration 671: 0.200483
# Cost after iteration 672: 0.200185
# Cost after iteration 673: 0.199892
# Cost after iteration 674: 0.199605
# Cost after iteration 675: 0.199324
# Cost after iteration 676: 0.199050
# Cost after iteration 677: 0.198781
# Cost after iteration 678: 0.198519
# Cost after iteration 679: 0.198263
# Cost after iteration 680: 0.198016
# Cost after iteration 681: 0.197775
# Cost after iteration 682: 0.197546
# Cost after iteration 683: 0.197327
# Cost after iteration 684: 0.197125
# Cost after iteration 685: 0.196938
# Cost after iteration 686: 0.196785
# Cost after iteration 687: 0.196657
# Cost after iteration 688: 0.196602
# Cost after iteration 689: 0.196600
# Cost after iteration 690: 0.196780
# Cost after iteration 691: 0.197075
# Cost after iteration 692: 0.197882
# Cost after iteration 693: 0.198953
# Cost after iteration 694: 0.201640
# Cost after iteration 695: 0.204880
# Cost after iteration 696: 0.213747
# Cost after iteration 697: 0.222581
# Cost after iteration 698: 0.250899
# Cost after iteration 699: 0.266228
# Cost after iteration 700: 0.348438
# Cost after iteration 701: 0.390539
# Cost after iteration 702: 0.664599
# Cost after iteration 703: 0.514224
# Cost after iteration 704: 0.593378
# Cost after iteration 705: 0.311493
# Cost after iteration 706: 0.255686
# Cost after iteration 707: 0.222051
# Cost after iteration 708: 0.211865
# Cost after iteration 709: 0.208286
# Cost after iteration 710: 0.206832
# Cost after iteration 711: 0.205901
# Cost after iteration 712: 0.205249
# Cost after iteration 713: 0.204697
# Cost after iteration 714: 0.204205
# Cost after iteration 715: 0.203744
# Cost after iteration 716: 0.203306
# Cost after iteration 717: 0.202885
# Cost after iteration 718: 0.202478
# Cost after iteration 719: 0.202085
# Cost after iteration 720: 0.201702
# Cost after iteration 721: 0.201330
# Cost after iteration 722: 0.200969
# Cost after iteration 723: 0.200616
# Cost after iteration 724: 0.200273
# Cost after iteration 725: 0.199938
# Cost after iteration 726: 0.199611
# Cost after iteration 727: 0.199292
# Cost after iteration 728: 0.198981
# Cost after iteration 729: 0.198677
# Cost after iteration 730: 0.198380
# Cost after iteration 731: 0.198089
# Cost after iteration 732: 0.197805
# Cost after iteration 733: 0.197527
# Cost after iteration 734: 0.197256
# Cost after iteration 735: 0.196991
# Cost after iteration 736: 0.196731
# Cost after iteration 737: 0.196477
# Cost after iteration 738: 0.196229
# Cost after iteration 739: 0.195987
# Cost after iteration 740: 0.195749
# Cost after iteration 741: 0.195517
# Cost after iteration 742: 0.195291
# Cost after iteration 743: 0.195069
# Cost after iteration 744: 0.194852
# Cost after iteration 745: 0.194640
# Cost after iteration 746: 0.194433
# Cost after iteration 747: 0.194231
# Cost after iteration 748: 0.194033
# Cost after iteration 749: 0.193840
# Cost after iteration 750: 0.193651
# Cost after iteration 751: 0.193466
# Cost after iteration 752: 0.193286
# Cost after iteration 753: 0.193110
# Cost after iteration 754: 0.192938
# Cost after iteration 755: 0.192769
# Cost after iteration 756: 0.192605
# Cost after iteration 757: 0.192445
# Cost after iteration 758: 0.192288
# Cost after iteration 759: 0.192135
# Cost after iteration 760: 0.191985
# Cost after iteration 761: 0.191839
# Cost after iteration 762: 0.191696
# Cost after iteration 763: 0.191557
# Cost after iteration 764: 0.191421
# Cost after iteration 765: 0.191288
# Cost after iteration 766: 0.191158
# Cost after iteration 767: 0.191031
# Cost after iteration 768: 0.190907
# Cost after iteration 769: 0.190787
# Cost after iteration 770: 0.190671
# Cost after iteration 771: 0.190559
# Cost after iteration 772: 0.190453
# Cost after iteration 773: 0.190358
# Cost after iteration 774: 0.190282
# Cost after iteration 775: 0.190241
# Cost after iteration 776: 0.190273
# Cost after iteration 777: 0.190455
# Cost after iteration 778: 0.190979
# Cost after iteration 779: 0.192200
# Cost after iteration 780: 0.195220
# Cost after iteration 781: 0.201919
# Cost after iteration 782: 0.220340
# Cost after iteration 783: 0.266148
# Cost after iteration 784: 0.426412
# Cost after iteration 785: 0.632397
# Cost after iteration 786: 1.376520
# Cost after iteration 787: 0.288736
# Cost after iteration 788: 0.246964
# Cost after iteration 789: 0.212233
# Cost after iteration 790: 0.208842
# Cost after iteration 791: 0.206622
# Cost after iteration 792: 0.205297
# Cost after iteration 793: 0.204225
# Cost after iteration 794: 0.203339
# Cost after iteration 795: 0.202550
# Cost after iteration 796: 0.201836
# Cost after iteration 797: 0.201177
# Cost after iteration 798: 0.200563
# Cost after iteration 799: 0.199988
# Cost after iteration 800: 0.199448
# Cost after iteration 801: 0.198938
# Cost after iteration 802: 0.198457
# Cost after iteration 803: 0.198001
# Cost after iteration 804: 0.197569
# Cost after iteration 805: 0.197158
# Cost after iteration 806: 0.196768
# Cost after iteration 807: 0.196395
# Cost after iteration 808: 0.196041
# Cost after iteration 809: 0.195702
# Cost after iteration 810: 0.195378
# Cost after iteration 811: 0.195068
# Cost after iteration 812: 0.194771
# Cost after iteration 813: 0.194486
# Cost after iteration 814: 0.194212
# Cost after iteration 815: 0.193950
# Cost after iteration 816: 0.193697
# Cost after iteration 817: 0.193455
# Cost after iteration 818: 0.193221
# Cost after iteration 819: 0.192995
# Cost after iteration 820: 0.192778
# Cost after iteration 821: 0.192568
# Cost after iteration 822: 0.192366
# Cost after iteration 823: 0.192171
# Cost after iteration 824: 0.191982
# Cost after iteration 825: 0.191799
# Cost after iteration 826: 0.191623
# Cost after iteration 827: 0.191452
# Cost after iteration 828: 0.191286
# Cost after iteration 829: 0.191126
# Cost after iteration 830: 0.190971
# Cost after iteration 831: 0.190821
# Cost after iteration 832: 0.190675
# Cost after iteration 833: 0.190534
# Cost after iteration 834: 0.190397
# Cost after iteration 835: 0.190264
# Cost after iteration 836: 0.190136
# Cost after iteration 837: 0.190012
# Cost after iteration 838: 0.189893
# Cost after iteration 839: 0.189778
# Cost after iteration 840: 0.189669
# Cost after iteration 841: 0.189566
# Cost after iteration 842: 0.189473
# Cost after iteration 843: 0.189392
# Cost after iteration 844: 0.189332
# Cost after iteration 845: 0.189299
# Cost after iteration 846: 0.189326
# Cost after iteration 847: 0.189429
# Cost after iteration 848: 0.189725
# Cost after iteration 849: 0.190241
# Cost after iteration 850: 0.191473
# Cost after iteration 851: 0.193384
# Cost after iteration 852: 0.198327
# Cost after iteration 853: 0.205311
# Cost after iteration 854: 0.226205
# Cost after iteration 855: 0.245474
# Cost after iteration 856: 0.325022
# Cost after iteration 857: 0.339275
# Cost after iteration 858: 0.579703
# Cost after iteration 859: 0.561105
# Cost after iteration 860: 0.890050
# Cost after iteration 861: 0.249773
# Cost after iteration 862: 0.225047
# Cost after iteration 863: 0.207095
# Cost after iteration 864: 0.202916
# Cost after iteration 865: 0.201093
# Cost after iteration 866: 0.200163
# Cost after iteration 867: 0.199503
# Cost after iteration 868: 0.198951
# Cost after iteration 869: 0.198452
# Cost after iteration 870: 0.197988
# Cost after iteration 871: 0.197549
# Cost after iteration 872: 0.197134
# Cost after iteration 873: 0.196740
# Cost after iteration 874: 0.196365
# Cost after iteration 875: 0.196007
# Cost after iteration 876: 0.195666
# Cost after iteration 877: 0.195341
# Cost after iteration 878: 0.195030
# Cost after iteration 879: 0.194733
# Cost after iteration 880: 0.194448
# Cost after iteration 881: 0.194176
# Cost after iteration 882: 0.193914
# Cost after iteration 883: 0.193663
# Cost after iteration 884: 0.193422
# Cost after iteration 885: 0.193191
# Cost after iteration 886: 0.192968
# Cost after iteration 887: 0.192754
# Cost after iteration 888: 0.192547
# Cost after iteration 889: 0.192348
# Cost after iteration 890: 0.192156
# Cost after iteration 891: 0.191971
# Cost after iteration 892: 0.191792
# Cost after iteration 893: 0.191619
# Cost after iteration 894: 0.191452
# Cost after iteration 895: 0.191291
# Cost after iteration 896: 0.191135
# Cost after iteration 897: 0.190983
# Cost after iteration 898: 0.190837
# Cost after iteration 899: 0.190695
# Cost after iteration 900: 0.190557
# Cost after iteration 901: 0.190424
# Cost after iteration 902: 0.190294
# Cost after iteration 903: 0.190168
# Cost after iteration 904: 0.190046
# Cost after iteration 905: 0.189928
# Cost after iteration 906: 0.189813
# Cost after iteration 907: 0.189701
# Cost after iteration 908: 0.189592
# Cost after iteration 909: 0.189486
# Cost after iteration 910: 0.189383
# Cost after iteration 911: 0.189282
# Cost after iteration 912: 0.189185
# Cost after iteration 913: 0.189090
# Cost after iteration 914: 0.188997
# Cost after iteration 915: 0.188907
# Cost after iteration 916: 0.188818
# Cost after iteration 917: 0.188733
# Cost after iteration 918: 0.188649
# Cost after iteration 919: 0.188567
# Cost after iteration 920: 0.188487
# Cost after iteration 921: 0.188409
# Cost after iteration 922: 0.188333
# Cost after iteration 923: 0.188259
# Cost after iteration 924: 0.188186
# Cost after iteration 925: 0.188115
# Cost after iteration 926: 0.188045
# Cost after iteration 927: 0.187977
# Cost after iteration 928: 0.187911
# Cost after iteration 929: 0.187846
# Cost after iteration 930: 0.187782
# Cost after iteration 931: 0.187719
# Cost after iteration 932: 0.187658
# Cost after iteration 933: 0.187599
# Cost after iteration 934: 0.187540
# Cost after iteration 935: 0.187483
# Cost after iteration 936: 0.187427
# Cost after iteration 937: 0.187373
# Cost after iteration 938: 0.187321
# Cost after iteration 939: 0.187273
# Cost after iteration 940: 0.187231
# Cost after iteration 941: 0.187199
# Cost after iteration 942: 0.187189
# Cost after iteration 943: 0.187220
# Cost after iteration 944: 0.187340
# Cost after iteration 945: 0.187637
# Cost after iteration 946: 0.188338
# Cost after iteration 947: 0.189822
# Cost after iteration 948: 0.193333
# Cost after iteration 949: 0.200688
# Cost after iteration 950: 0.221107
# Cost after iteration 951: 0.268750
# Cost after iteration 952: 0.434379
# Cost after iteration 953: 0.545966
# Cost after iteration 954: 0.799418
# Cost after iteration 955: 0.367281
# Cost after iteration 956: 0.530344
# Cost after iteration 957: 0.238242
# Cost after iteration 958: 0.227094
# Cost after iteration 959: 0.205363
# Cost after iteration 960: 0.201556
# Cost after iteration 961: 0.198960
# Cost after iteration 962: 0.197748
# Cost after iteration 963: 0.196924
# Cost after iteration 964: 0.196339
# Cost after iteration 965: 0.195852
# Cost after iteration 966: 0.195425
# Cost after iteration 967: 0.195033
# Cost after iteration 968: 0.194668
# Cost after iteration 969: 0.194324
# Cost after iteration 970: 0.193998
# Cost after iteration 971: 0.193688
# Cost after iteration 972: 0.193393
# Cost after iteration 973: 0.193112
# Cost after iteration 974: 0.192844
# Cost after iteration 975: 0.192588
# Cost after iteration 976: 0.192344
# Cost after iteration 977: 0.192110
# Cost after iteration 978: 0.191886
# Cost after iteration 979: 0.191671
# Cost after iteration 980: 0.191466
# Cost after iteration 981: 0.191269
# Cost after iteration 982: 0.191080
# Cost after iteration 983: 0.190898
# Cost after iteration 984: 0.190724
# Cost after iteration 985: 0.190556
# Cost after iteration 986: 0.190395
# Cost after iteration 987: 0.190240
# Cost after iteration 988: 0.190091
# Cost after iteration 989: 0.189947
# Cost after iteration 990: 0.189809
# Cost after iteration 991: 0.189675
# Cost after iteration 992: 0.189546
# Cost after iteration 993: 0.189422
# Cost after iteration 994: 0.189302
# Cost after iteration 995: 0.189186
# Cost after iteration 996: 0.189074
# Cost after iteration 997: 0.188965
# Cost after iteration 998: 0.188860
# Cost after iteration 999: 0.188759
# Cost after iteration 1000: 0.188661
# Cost after iteration 1001: 0.188565
# Cost after iteration 1002: 0.188473
# Cost after iteration 1003: 0.188384
# Cost after iteration 1004: 0.188297
# Cost after iteration 1005: 0.188213
# Cost after iteration 1006: 0.188131
# Cost after iteration 1007: 0.188052
# Cost after iteration 1008: 0.187975
# Cost after iteration 1009: 0.187900
# Cost after iteration 1010: 0.187828
# Cost after iteration 1011: 0.187757
# Cost after iteration 1012: 0.187688
# Cost after iteration 1013: 0.187621
# Cost after iteration 1014: 0.187556
# Cost after iteration 1015: 0.187493
# Cost after iteration 1016: 0.187431
# Cost after iteration 1017: 0.187370
# Cost after iteration 1018: 0.187312
# Cost after iteration 1019: 0.187254
# Cost after iteration 1020: 0.187199
# Cost after iteration 1021: 0.187144
# Cost after iteration 1022: 0.187091
# Cost after iteration 1023: 0.187039
# Cost after iteration 1024: 0.186989
# Cost after iteration 1025: 0.186940
# Cost after iteration 1026: 0.186893
# Cost after iteration 1027: 0.186847
# Cost after iteration 1028: 0.186804
# Cost after iteration 1029: 0.186765
# Cost after iteration 1030: 0.186732
# Cost after iteration 1031: 0.186707
# Cost after iteration 1032: 0.186699
# Cost after iteration 1033: 0.186717
# Cost after iteration 1034: 0.186789
# Cost after iteration 1035: 0.186949
# Cost after iteration 1036: 0.187299
# Cost after iteration 1037: 0.187945
# Cost after iteration 1038: 0.189330
# Cost after iteration 1039: 0.191754
# Cost after iteration 1040: 0.197387
# Cost after iteration 1041: 0.206983
# Cost after iteration 1042: 0.233480
# Cost after iteration 1043: 0.277969
# Cost after iteration 1044: 0.446708
# Cost after iteration 1045: 0.594011
# Cost after iteration 1046: 1.412835
# Cost after iteration 1047: 0.216339
# Cost after iteration 1048: 0.206513
# Cost after iteration 1049: 0.202802
# Cost after iteration 1050: 0.201356
# Cost after iteration 1051: 0.200371
# Cost after iteration 1052: 0.199555
# Cost after iteration 1053: 0.198820
# Cost after iteration 1054: 0.198143
# Cost after iteration 1055: 0.197514
# Cost after iteration 1056: 0.196927
# Cost after iteration 1057: 0.196379
# Cost after iteration 1058: 0.195865
# Cost after iteration 1059: 0.195384
# Cost after iteration 1060: 0.194932
# Cost after iteration 1061: 0.194508
# Cost after iteration 1062: 0.194108
# Cost after iteration 1063: 0.193733
# Cost after iteration 1064: 0.193378
# Cost after iteration 1065: 0.193045
# Cost after iteration 1066: 0.192729
# Cost after iteration 1067: 0.192431
# Cost after iteration 1068: 0.192150
# Cost after iteration 1069: 0.191883
# Cost after iteration 1070: 0.191631
# Cost after iteration 1071: 0.191392
# Cost after iteration 1072: 0.191165
# Cost after iteration 1073: 0.190950
# Cost after iteration 1074: 0.190746
# Cost after iteration 1075: 0.190551
# Cost after iteration 1076: 0.190367
# Cost after iteration 1077: 0.190191
# Cost after iteration 1078: 0.190023
# Cost after iteration 1079: 0.189863
# Cost after iteration 1080: 0.189711
# Cost after iteration 1081: 0.189565
# Cost after iteration 1082: 0.189426
# Cost after iteration 1083: 0.189293
# Cost after iteration 1084: 0.189166
# Cost after iteration 1085: 0.189044
# Cost after iteration 1086: 0.188927
# Cost after iteration 1087: 0.188815
# Cost after iteration 1088: 0.188707
# Cost after iteration 1089: 0.188604
# Cost after iteration 1090: 0.188505
# Cost after iteration 1091: 0.188409
# Cost after iteration 1092: 0.188317
# Cost after iteration 1093: 0.188229
# Cost after iteration 1094: 0.188144
# Cost after iteration 1095: 0.188062
# Cost after iteration 1096: 0.187982
# Cost after iteration 1097: 0.187906
# Cost after iteration 1098: 0.187832
# Cost after iteration 1099: 0.187760
# Cost after iteration 1100: 0.187691
# Cost after iteration 1101: 0.187624
# Cost after iteration 1102: 0.187559
# Cost after iteration 1103: 0.187496
# Cost after iteration 1104: 0.187435
# Cost after iteration 1105: 0.187376
# Cost after iteration 1106: 0.187319
# Cost after iteration 1107: 0.187263
# Cost after iteration 1108: 0.187209
# Cost after iteration 1109: 0.187156
# Cost after iteration 1110: 0.187105
# Cost after iteration 1111: 0.187055
# Cost after iteration 1112: 0.187006
# Cost after iteration 1113: 0.186959
# Cost after iteration 1114: 0.186913
# Cost after iteration 1115: 0.186868
# Cost after iteration 1116: 0.186824
# Cost after iteration 1117: 0.186781
# Cost after iteration 1118: 0.186739
# Cost after iteration 1119: 0.186698
# Cost after iteration 1120: 0.186658
# Cost after iteration 1121: 0.186618
# Cost after iteration 1122: 0.186580
# Cost after iteration 1123: 0.186543
# Cost after iteration 1124: 0.186506
# Cost after iteration 1125: 0.186470
# Cost after iteration 1126: 0.186434
# Cost after iteration 1127: 0.186400
# Cost after iteration 1128: 0.186366
# Cost after iteration 1129: 0.186333
# Cost after iteration 1130: 0.186300
# Cost after iteration 1131: 0.186268
# Cost after iteration 1132: 0.186236
# Cost after iteration 1133: 0.186205
# Cost after iteration 1134: 0.186175
# Cost after iteration 1135: 0.186145
# Cost after iteration 1136: 0.186116
# Cost after iteration 1137: 0.186088
# Cost after iteration 1138: 0.186062
# Cost after iteration 1139: 0.186037
# Cost after iteration 1140: 0.186016
# Cost after iteration 1141: 0.186002
# Cost after iteration 1142: 0.186000
# Cost after iteration 1143: 0.186023
# Cost after iteration 1144: 0.186094
# Cost after iteration 1145: 0.186270
# Cost after iteration 1146: 0.186634
# Cost after iteration 1147: 0.187469
# Cost after iteration 1148: 0.189061
# Cost after iteration 1149: 0.192997
# Cost after iteration 1150: 0.200128
# Cost after iteration 1151: 0.220720
# Cost after iteration 1152: 0.253055
# Cost after iteration 1153: 0.374270
# Cost after iteration 1154: 0.469654
# Cost after iteration 1155: 1.143622
# Cost after iteration 1156: 0.327746
# Cost after iteration 1157: 0.328681
# Cost after iteration 1158: 0.246126
# Cost after iteration 1159: 0.223564
# Cost after iteration 1160: 0.207976
# Cost after iteration 1161: 0.200669
# Cost after iteration 1162: 0.197489
# Cost after iteration 1163: 0.195978
# Cost after iteration 1164: 0.195155
# Cost after iteration 1165: 0.194591
# Cost after iteration 1166: 0.194136
# Cost after iteration 1167: 0.193735
# Cost after iteration 1168: 0.193367
# Cost after iteration 1169: 0.193025
# Cost after iteration 1170: 0.192704
# Cost after iteration 1171: 0.192402
# Cost after iteration 1172: 0.192116
# Cost after iteration 1173: 0.191846
# Cost after iteration 1174: 0.191590
# Cost after iteration 1175: 0.191349
# Cost after iteration 1176: 0.191119
# Cost after iteration 1177: 0.190902
# Cost after iteration 1178: 0.190695
# Cost after iteration 1179: 0.190499
# Cost after iteration 1180: 0.190313
# Cost after iteration 1181: 0.190136
# Cost after iteration 1182: 0.189967
# Cost after iteration 1183: 0.189807
# Cost after iteration 1184: 0.189654
# Cost after iteration 1185: 0.189508
# Cost after iteration 1186: 0.189369
# Cost after iteration 1187: 0.189236
# Cost after iteration 1188: 0.189109
# Cost after iteration 1189: 0.188987
# Cost after iteration 1190: 0.188871
# Cost after iteration 1191: 0.188760
# Cost after iteration 1192: 0.188653
# Cost after iteration 1193: 0.188551
# Cost after iteration 1194: 0.188453
# Cost after iteration 1195: 0.188359
# Cost after iteration 1196: 0.188268
# Cost after iteration 1197: 0.188181
# Cost after iteration 1198: 0.188097
# Cost after iteration 1199: 0.188017
# Cost after iteration 1200: 0.187939
# Cost after iteration 1201: 0.187864
# Cost after iteration 1202: 0.187792
# Cost after iteration 1203: 0.187722
# Cost after iteration 1204: 0.187654
# Cost after iteration 1205: 0.187589
# Cost after iteration 1206: 0.187526
# Cost after iteration 1207: 0.187465
# Cost after iteration 1208: 0.187406
# Cost after iteration 1209: 0.187348
# Cost after iteration 1210: 0.187293
# Cost after iteration 1211: 0.187239
# Cost after iteration 1212: 0.187186
# Cost after iteration 1213: 0.187136
# Cost after iteration 1214: 0.187086
# Cost after iteration 1215: 0.187038
# Cost after iteration 1216: 0.186991
# Cost after iteration 1217: 0.186945
# Cost after iteration 1218: 0.186901
# Cost after iteration 1219: 0.186858
# Cost after iteration 1220: 0.186815
# Cost after iteration 1221: 0.186774
# Cost after iteration 1222: 0.186734
# Cost after iteration 1223: 0.186694
# Cost after iteration 1224: 0.186656
# Cost after iteration 1225: 0.186618
# Cost after iteration 1226: 0.186582
# Cost after iteration 1227: 0.186546
# Cost after iteration 1228: 0.186510
# Cost after iteration 1229: 0.186476
# Cost after iteration 1230: 0.186442
# Cost after iteration 1231: 0.186409
# Cost after iteration 1232: 0.186377
# Cost after iteration 1233: 0.186346
# Cost after iteration 1234: 0.186315
# Cost after iteration 1235: 0.186285
# Cost after iteration 1236: 0.186257
# Cost after iteration 1237: 0.186230
# Cost after iteration 1238: 0.186206
# Cost after iteration 1239: 0.186186
# Cost after iteration 1240: 0.186172
# Cost after iteration 1241: 0.186169
# Cost after iteration 1242: 0.186184
# Cost after iteration 1243: 0.186233
# Cost after iteration 1244: 0.186338
# Cost after iteration 1245: 0.186554
# Cost after iteration 1246: 0.186947
# Cost after iteration 1247: 0.187730
# Cost after iteration 1248: 0.189084
# Cost after iteration 1249: 0.191918
# Cost after iteration 1250: 0.196677
# Cost after iteration 1251: 0.207964
# Cost after iteration 1252: 0.226833
# Cost after iteration 1253: 0.285830
# Cost after iteration 1254: 0.375421
# Cost after iteration 1255: 0.708926
# Cost after iteration 1256: 0.536407
# Cost after iteration 1257: 0.901189
# Cost after iteration 1258: 0.278833
# Cost after iteration 1259: 0.234381
# Cost after iteration 1260: 0.208599
# Cost after iteration 1261: 0.200943
# Cost after iteration 1262: 0.198528
# Cost after iteration 1263: 0.197504
# Cost after iteration 1264: 0.196863
# Cost after iteration 1265: 0.196345
# Cost after iteration 1266: 0.195881
# Cost after iteration 1267: 0.195450
# Cost after iteration 1268: 0.195045
# Cost after iteration 1269: 0.194661
# Cost after iteration 1270: 0.194298
# Cost after iteration 1271: 0.193954
# Cost after iteration 1272: 0.193628
# Cost after iteration 1273: 0.193317
# Cost after iteration 1274: 0.193023
# Cost after iteration 1275: 0.192743
# Cost after iteration 1276: 0.192476
# Cost after iteration 1277: 0.192223
# Cost after iteration 1278: 0.191981
# Cost after iteration 1279: 0.191751
# Cost after iteration 1280: 0.191532
# Cost after iteration 1281: 0.191322
# Cost after iteration 1282: 0.191123
# Cost after iteration 1283: 0.190932
# Cost after iteration 1284: 0.190750
# Cost after iteration 1285: 0.190576
# Cost after iteration 1286: 0.190410
# Cost after iteration 1287: 0.190250
# Cost after iteration 1288: 0.190098
# Cost after iteration 1289: 0.189952
# Cost after iteration 1290: 0.189812
# Cost after iteration 1291: 0.189678
# Cost after iteration 1292: 0.189549
# Cost after iteration 1293: 0.189425
# Cost after iteration 1294: 0.189307
# Cost after iteration 1295: 0.189193
# Cost after iteration 1296: 0.189083
# Cost after iteration 1297: 0.188978
# Cost after iteration 1298: 0.188876
# Cost after iteration 1299: 0.188778
# Cost after iteration 1300: 0.188684
# Cost after iteration 1301: 0.188593
# Cost after iteration 1302: 0.188506
# Cost after iteration 1303: 0.188421
# Cost after iteration 1304: 0.188340
# Cost after iteration 1305: 0.188261
# Cost after iteration 1306: 0.188185
# Cost after iteration 1307: 0.188111
# Cost after iteration 1308: 0.188040
# Cost after iteration 1309: 0.187971
# Cost after iteration 1310: 0.187905
# Cost after iteration 1311: 0.187840
# Cost after iteration 1312: 0.187777
# Cost after iteration 1313: 0.187716
# Cost after iteration 1314: 0.187657
# Cost after iteration 1315: 0.187600
# Cost after iteration 1316: 0.187545
# Cost after iteration 1317: 0.187491
# Cost after iteration 1318: 0.187438
# Cost after iteration 1319: 0.187387
# Cost after iteration 1320: 0.187337
# Cost after iteration 1321: 0.187289
# Cost after iteration 1322: 0.187242
# Cost after iteration 1323: 0.187196
# Cost after iteration 1324: 0.187151
# Cost after iteration 1325: 0.187108
# Cost after iteration 1326: 0.187065
# Cost after iteration 1327: 0.187024
# Cost after iteration 1328: 0.186983
# Cost after iteration 1329: 0.186943
# Cost after iteration 1330: 0.186905
# Cost after iteration 1331: 0.186867
# Cost after iteration 1332: 0.186830
# Cost after iteration 1333: 0.186794
# Cost after iteration 1334: 0.186758
# Cost after iteration 1335: 0.186724
# Cost after iteration 1336: 0.186690
# Cost after iteration 1337: 0.186657
# Cost after iteration 1338: 0.186624
# Cost after iteration 1339: 0.186592
# Cost after iteration 1340: 0.186561
# Cost after iteration 1341: 0.186530
# Cost after iteration 1342: 0.186500
# Cost after iteration 1343: 0.186470
# Cost after iteration 1344: 0.186441
# Cost after iteration 1345: 0.186413
# Cost after iteration 1346: 0.186385
# Cost after iteration 1347: 0.186357
# Cost after iteration 1348: 0.186330
# Cost after iteration 1349: 0.186303
# Cost after iteration 1350: 0.186277
# Cost after iteration 1351: 0.186251
# Cost after iteration 1352: 0.186226
# Cost after iteration 1353: 0.186201
# Cost after iteration 1354: 0.186176
# Cost after iteration 1355: 0.186152
# Cost after iteration 1356: 0.186128
# Cost after iteration 1357: 0.186105
# Cost after iteration 1358: 0.186082
# Cost after iteration 1359: 0.186059
# Cost after iteration 1360: 0.186036
# Cost after iteration 1361: 0.186014
# Cost after iteration 1362: 0.185992
# Cost after iteration 1363: 0.185970
# ...
# Cost after iteration 2560: 0.192996
# Cost after iteration 2561: 0.191986
# Cost after iteration 2562: 0.190996
# Cost after iteration 2563: 0.190403
# Cost after iteration 2564: 0.189845
# Cost after iteration 2565: 0.189499
# Cost after iteration 2566: 0.189170
# Cost after iteration 2567: 0.188960
# Cost after iteration 2568: 0.188752
# Cost after iteration 2569: 0.188616
# Cost after iteration 2570: 0.188474
# Cost after iteration 2571: 0.188381
# Cost after iteration 2572: 0.188278
# Cost after iteration 2573: 0.188211
# Cost after iteration 2574: 0.188132
# Cost after iteration 2575: 0.188084
# Cost after iteration 2576: 0.188022
# Cost after iteration 2577: 0.187988
# Cost after iteration 2578: 0.187939
# Cost after iteration 2579: 0.187919
# Cost after iteration 2580: 0.187882
# Cost after iteration 2581: 0.187877
# Cost after iteration 2582: 0.187853
# Cost after iteration 2583: 0.187868
# Cost after iteration 2584: 0.187858
# Cost after iteration 2585: 0.187903
# Cost after iteration 2586: 0.187913
# Cost after iteration 2587: 0.188003
# Cost after iteration 2588: 0.188043
# Cost after iteration 2589: 0.188206
# Cost after iteration 2590: 0.188294
# Cost after iteration 2591: 0.188588
# Cost after iteration 2592: 0.188754
# Cost after iteration 2593: 0.189289
# Cost after iteration 2594: 0.189594
# Cost after iteration 2595: 0.190602
# Cost after iteration 2596: 0.191168
# Cost after iteration 2597: 0.193168
# Cost after iteration 2598: 0.194257
# Cost after iteration 2599: 0.198449
# Cost after iteration 2600: 0.200527
# Cost after iteration 2601: 0.209541
# Cost after iteration 2602: 0.212127
# Cost after iteration 2603: 0.229758
# Cost after iteration 2604: 0.225581
# Cost after iteration 2605: 0.250338
# Cost after iteration 2606: 0.231178
# Cost after iteration 2607: 0.251699
# Cost after iteration 2608: 0.228689
# Cost after iteration 2609: 0.241334
# Cost after iteration 2610: 0.227994
# Cost after iteration 2611: 0.239405
# Cost after iteration 2612: 0.234408
# Cost after iteration 2613: 0.251970
# Cost after iteration 2614: 0.250849
# Cost after iteration 2615: 0.281865
# Cost after iteration 2616: 0.270385
# Cost after iteration 2617: 0.302421
# Cost after iteration 2618: 0.263484
# Cost after iteration 2619: 0.268848
# Cost after iteration 2620: 0.232437
# Cost after iteration 2621: 0.220237
# Cost after iteration 2622: 0.205157
# Cost after iteration 2623: 0.198570
# Cost after iteration 2624: 0.194266
# Cost after iteration 2625: 0.192600
# Cost after iteration 2626: 0.191425
# Cost after iteration 2627: 0.190884
# Cost after iteration 2628: 0.190429
# Cost after iteration 2629: 0.190162
# Cost after iteration 2630: 0.189924
# Cost after iteration 2631: 0.189753
# Cost after iteration 2632: 0.189596
# Cost after iteration 2633: 0.189467
# Cost after iteration 2634: 0.189347
# Cost after iteration 2635: 0.189240
# Cost after iteration 2636: 0.189139
# Cost after iteration 2637: 0.189045
# Cost after iteration 2638: 0.188956
# Cost after iteration 2639: 0.188872
# Cost after iteration 2640: 0.188791
# Cost after iteration 2641: 0.188714
# Cost after iteration 2642: 0.188640
# Cost after iteration 2643: 0.188568
# Cost after iteration 2644: 0.188500
# Cost after iteration 2645: 0.188434
# Cost after iteration 2646: 0.188370
# Cost after iteration 2647: 0.188308
# Cost after iteration 2648: 0.188248
# Cost after iteration 2649: 0.188190
# Cost after iteration 2650: 0.188134
# Cost after iteration 2651: 0.188080
# Cost after iteration 2652: 0.188027
# Cost after iteration 2653: 0.187977
# Cost after iteration 2654: 0.187927
# Cost after iteration 2655: 0.187879
# Cost after iteration 2656: 0.187833
# Cost after iteration 2657: 0.187788
# Cost after iteration 2658: 0.187744
# Cost after iteration 2659: 0.187702
# Cost after iteration 2660: 0.187661
# Cost after iteration 2661: 0.187622
# Cost after iteration 2662: 0.187583
# Cost after iteration 2663: 0.187547
# Cost after iteration 2664: 0.187511
# Cost after iteration 2665: 0.187478
# Cost after iteration 2666: 0.187446
# Cost after iteration 2667: 0.187417
# Cost after iteration 2668: 0.187390
# Cost after iteration 2669: 0.187368
# Cost after iteration 2670: 0.187348
# Cost after iteration 2671: 0.187336
# Cost after iteration 2672: 0.187327
# Cost after iteration 2673: 0.187335
# Cost after iteration 2674: 0.187349
# Cost after iteration 2675: 0.187396
# Cost after iteration 2676: 0.187452
# Cost after iteration 2677: 0.187584
# Cost after iteration 2678: 0.187729
# Cost after iteration 2679: 0.188054
# Cost after iteration 2680: 0.188389
# Cost after iteration 2681: 0.189192
# Cost after iteration 2682: 0.189961
# Cost after iteration 2683: 0.192041
# Cost after iteration 2684: 0.193901
# Cost after iteration 2685: 0.199690
# Cost after iteration 2686: 0.204284
# Cost after iteration 2687: 0.220765
# Cost after iteration 2688: 0.225928
# Cost after iteration 2689: 0.264273
# Cost after iteration 2690: 0.244792
# Cost after iteration 2691: 0.290572
# Cost after iteration 2692: 0.238463
# Cost after iteration 2693: 0.256958
# Cost after iteration 2694: 0.219682
# Cost after iteration 2695: 0.223608
# Cost after iteration 2696: 0.212256
# Cost after iteration 2697: 0.214302
# Cost after iteration 2698: 0.209832
# Cost after iteration 2699: 0.212108
# Cost after iteration 2700: 0.210118
# Cost after iteration 2701: 0.213299
# Cost after iteration 2702: 0.212005
# Cost after iteration 2703: 0.216003
# Cost after iteration 2704: 0.214173
# Cost after iteration 2705: 0.218198
# Cost after iteration 2706: 0.214959
# Cost after iteration 2707: 0.217612
# Cost after iteration 2708: 0.212769
# Cost after iteration 2709: 0.212813
# Cost after iteration 2710: 0.207281
# Cost after iteration 2711: 0.205093
# Cost after iteration 2712: 0.200422
# Cost after iteration 2713: 0.197897
# Cost after iteration 2714: 0.194949
# Cost after iteration 2715: 0.193273
# Cost after iteration 2716: 0.191743
# Cost after iteration 2717: 0.190849
# Cost after iteration 2718: 0.190099
# Cost after iteration 2719: 0.189639
# Cost after iteration 2720: 0.189253
# Cost after iteration 2721: 0.189002
# Cost after iteration 2722: 0.188781
# Cost after iteration 2723: 0.188629
# Cost after iteration 2724: 0.188488
# Cost after iteration 2725: 0.188384
# Cost after iteration 2726: 0.188284
# Cost after iteration 2727: 0.188206
# Cost after iteration 2728: 0.188129
# Cost after iteration 2729: 0.188067
# Cost after iteration 2730: 0.188004
# Cost after iteration 2731: 0.187952
# Cost after iteration 2732: 0.187898
# Cost after iteration 2733: 0.187855
# Cost after iteration 2734: 0.187808
# Cost after iteration 2735: 0.187771
# Cost after iteration 2736: 0.187731
# Cost after iteration 2737: 0.187701
# Cost after iteration 2738: 0.187667
# Cost after iteration 2739: 0.187643
# Cost after iteration 2740: 0.187616
# Cost after iteration 2741: 0.187602
# Cost after iteration 2742: 0.187583
# Cost after iteration 2743: 0.187582
# Cost after iteration 2744: 0.187574
# Cost after iteration 2745: 0.187594
# Cost after iteration 2746: 0.187602
# Cost after iteration 2747: 0.187655
# Cost after iteration 2748: 0.187690
# Cost after iteration 2749: 0.187801
# Cost after iteration 2750: 0.187880
# Cost after iteration 2751: 0.188097
# Cost after iteration 2752: 0.188254
# Cost after iteration 2753: 0.188679
# Cost after iteration 2754: 0.188980
# Cost after iteration 2755: 0.189836
# Cost after iteration 2756: 0.190417
# Cost after iteration 2757: 0.192229
# Cost after iteration 2758: 0.193409
# Cost after iteration 2759: 0.197490
# Cost after iteration 2760: 0.199933
# Cost after iteration 2761: 0.209469
# Cost after iteration 2762: 0.213035
# Cost after iteration 2763: 0.233333
# Cost after iteration 2764: 0.228721
# Cost after iteration 2765: 0.258494
# Cost after iteration 2766: 0.234448
# Cost after iteration 2767: 0.257822
# Cost after iteration 2768: 0.229134
# Cost after iteration 2769: 0.241334
# Cost after iteration 2770: 0.226472
# Cost after iteration 2771: 0.236745
# Cost after iteration 2772: 0.231903
# Cost after iteration 2773: 0.248040
# Cost after iteration 2774: 0.247763
# Cost after iteration 2775: 0.277829
# Cost after iteration 2776: 0.269082
# Cost after iteration 2777: 0.303451
# Cost after iteration 2778: 0.265781
# Cost after iteration 2779: 0.274255
# Cost after iteration 2780: 0.235014
# Cost after iteration 2781: 0.222950
# Cost after iteration 2782: 0.206426
# Cost after iteration 2783: 0.199084
# Cost after iteration 2784: 0.194421
# Cost after iteration 2785: 0.192601
# Cost after iteration 2786: 0.191411
# Cost after iteration 2787: 0.190863
# Cost after iteration 2788: 0.190421
# Cost after iteration 2789: 0.190159
# Cost after iteration 2790: 0.189927
# Cost after iteration 2791: 0.189758
# Cost after iteration 2792: 0.189604
# Cost after iteration 2793: 0.189476
# Cost after iteration 2794: 0.189357
# Cost after iteration 2795: 0.189250
# Cost after iteration 2796: 0.189149
# Cost after iteration 2797: 0.189055
# Cost after iteration 2798: 0.188966
# Cost after iteration 2799: 0.188881
# Cost after iteration 2800: 0.188800
# Cost after iteration 2801: 0.188723
# Cost after iteration 2802: 0.188648
# Cost after iteration 2803: 0.188577
# Cost after iteration 2804: 0.188508
# Cost after iteration 2805: 0.188441
# Cost after iteration 2806: 0.188377
# Cost after iteration 2807: 0.188315
# Cost after iteration 2808: 0.188255
# Cost after iteration 2809: 0.188197
# Cost after iteration 2810: 0.188141
# Cost after iteration 2811: 0.188087
# Cost after iteration 2812: 0.188034
# Cost after iteration 2813: 0.187983
# Cost after iteration 2814: 0.187934
# Cost after iteration 2815: 0.187886
# Cost after iteration 2816: 0.187840
# Cost after iteration 2817: 0.187795
# Cost after iteration 2818: 0.187751
# Cost after iteration 2819: 0.187709
# Cost after iteration 2820: 0.187668
# Cost after iteration 2821: 0.187629
# Cost after iteration 2822: 0.187591
# Cost after iteration 2823: 0.187554
# Cost after iteration 2824: 0.187519
# Cost after iteration 2825: 0.187486
# Cost after iteration 2826: 0.187454
# Cost after iteration 2827: 0.187426
# Cost after iteration 2828: 0.187399
# Cost after iteration 2829: 0.187377
# Cost after iteration 2830: 0.187358
# Cost after iteration 2831: 0.187348
# Cost after iteration 2832: 0.187341
# Cost after iteration 2833: 0.187352
# Cost after iteration 2834: 0.187369
# Cost after iteration 2835: 0.187422
# Cost after iteration 2836: 0.187486
# Cost after iteration 2837: 0.187632
# Cost after iteration 2838: 0.187791
# Cost after iteration 2839: 0.188151
# Cost after iteration 2840: 0.188519
# Cost after iteration 2841: 0.189413
# Cost after iteration 2842: 0.190261
# Cost after iteration 2843: 0.192596
# Cost after iteration 2844: 0.194669
# Cost after iteration 2845: 0.201226
# Cost after iteration 2846: 0.206265
# Cost after iteration 2847: 0.224808
# Cost after iteration 2848: 0.228772
# Cost after iteration 2849: 0.269741
# Cost after iteration 2850: 0.245701
# Cost after iteration 2851: 0.289674
# Cost after iteration 2852: 0.236008
# Cost after iteration 2853: 0.251284
# Cost after iteration 2854: 0.217818
# Cost after iteration 2855: 0.221015
# Cost after iteration 2856: 0.210945
# Cost after iteration 2857: 0.212580
# Cost after iteration 2858: 0.208417
# Cost after iteration 2859: 0.210205
# Cost after iteration 2860: 0.208247
# Cost after iteration 2861: 0.210665
# Cost after iteration 2862: 0.209312
# Cost after iteration 2863: 0.212147
# Cost after iteration 2864: 0.210401
# Cost after iteration 2865: 0.212971
# Cost after iteration 2866: 0.210277
# Cost after iteration 2867: 0.211686
# Cost after iteration 2868: 0.208033
# Cost after iteration 2869: 0.207718
# Cost after iteration 2870: 0.203736
# Cost after iteration 2871: 0.202118
# Cost after iteration 2872: 0.198721
# Cost after iteration 2873: 0.196898
# Cost after iteration 2874: 0.194585
# Cost after iteration 2875: 0.193245
# Cost after iteration 2876: 0.191891
# Cost after iteration 2877: 0.191074
# Cost after iteration 2878: 0.190323
# Cost after iteration 2879: 0.189851
# Cost after iteration 2880: 0.189427
# Cost after iteration 2881: 0.189148
# Cost after iteration 2882: 0.188894
# Cost after iteration 2883: 0.188720
# Cost after iteration 2884: 0.188555
# Cost after iteration 2885: 0.188438
# Cost after iteration 2886: 0.188323
# Cost after iteration 2887: 0.188238
# Cost after iteration 2888: 0.188152
# Cost after iteration 2889: 0.188087
# Cost after iteration 2890: 0.188019
# Cost after iteration 2891: 0.187969
# Cost after iteration 2892: 0.187914
# Cost after iteration 2893: 0.187874
# Cost after iteration 2894: 0.187828
# Cost after iteration 2895: 0.187798
# Cost after iteration 2896: 0.187761
# Cost after iteration 2897: 0.187740
# Cost after iteration 2898: 0.187712
# Cost after iteration 2899: 0.187703
# Cost after iteration 2900: 0.187684
# Cost after iteration 2901: 0.187692
# Cost after iteration 2902: 0.187686
# Cost after iteration 2903: 0.187717
# Cost after iteration 2904: 0.187730
# Cost after iteration 2905: 0.187799
# Cost after iteration 2906: 0.187841
# Cost after iteration 2907: 0.187975
# Cost after iteration 2908: 0.188062
# Cost after iteration 2909: 0.188312
# Cost after iteration 2910: 0.188479
# Cost after iteration 2911: 0.188948
# Cost after iteration 2912: 0.189256
# Cost after iteration 2913: 0.190166
# Cost after iteration 2914: 0.190745
# Cost after iteration 2915: 0.192602
# Cost after iteration 2916: 0.193737
# Cost after iteration 2917: 0.197761
# Cost after iteration 2918: 0.200020
# Cost after iteration 2919: 0.209048
# Cost after iteration 2920: 0.212279
# Cost after iteration 2921: 0.230906
# Cost after iteration 2922: 0.227358
# Cost after iteration 2923: 0.254849
# Cost after iteration 2924: 0.234169
# Cost after iteration 2925: 0.257304
# Cost after iteration 2926: 0.231581
# Cost after iteration 2927: 0.245716
# Cost after iteration 2928: 0.231720
# Cost after iteration 2929: 0.245813
# Cost after iteration 2930: 0.241894
# Cost after iteration 2931: 0.266532
# Cost after iteration 2932: 0.264684
# Cost after iteration 2933: 0.305218
# Cost after iteration 2934: 0.279521
# Cost after iteration 2935: 0.305859
# Cost after iteration 2936: 0.255330
# Cost after iteration 2937: 0.249145
# Cost after iteration 2938: 0.220068
# Cost after iteration 2939: 0.208129
# Cost after iteration 2940: 0.198716
# Cost after iteration 2941: 0.194996
# Cost after iteration 2942: 0.192650
# Cost after iteration 2943: 0.191701
# Cost after iteration 2944: 0.190975
# Cost after iteration 2945: 0.190597
# Cost after iteration 2946: 0.190275
# Cost after iteration 2947: 0.190061
# Cost after iteration 2948: 0.189872
# Cost after iteration 2949: 0.189723
# Cost after iteration 2950: 0.189587
# Cost after iteration 2951: 0.189468
# Cost after iteration 2952: 0.189356
# Cost after iteration 2953: 0.189254
# Cost after iteration 2954: 0.189157
# Cost after iteration 2955: 0.189066
# Cost after iteration 2956: 0.188979
# Cost after iteration 2957: 0.188895
# Cost after iteration 2958: 0.188815
# Cost after iteration 2959: 0.188739
# Cost after iteration 2960: 0.188665
# Cost after iteration 2961: 0.188594
# Cost after iteration 2962: 0.188525
# Cost after iteration 2963: 0.188459
# Cost after iteration 2964: 0.188395
# Cost after iteration 2965: 0.188333
# Cost after iteration 2966: 0.188274
# Cost after iteration 2967: 0.188216
# Cost after iteration 2968: 0.188160
# Cost after iteration 2969: 0.188105
# Cost after iteration 2970: 0.188053
# Cost after iteration 2971: 0.188001
# Cost after iteration 2972: 0.187952
# Cost after iteration 2973: 0.187904
# Cost after iteration 2974: 0.187857
# Cost after iteration 2975: 0.187812
# Cost after iteration 2976: 0.187768
# Cost after iteration 2977: 0.187725
# Cost after iteration 2978: 0.187684
# Cost after iteration 2979: 0.187643
# Cost after iteration 2980: 0.187604
# Cost after iteration 2981: 0.187567
# Cost after iteration 2982: 0.187530
# Cost after iteration 2983: 0.187495
# Cost after iteration 2984: 0.187461
# Cost after iteration 2985: 0.187429
# Cost after iteration 2986: 0.187398
# Cost after iteration 2987: 0.187370
# Cost after iteration 2988: 0.187343
# Cost after iteration 2989: 0.187321
# Cost after iteration 2990: 0.187301
# Cost after iteration 2991: 0.187288
# Cost after iteration 2992: 0.187280
# Cost after iteration 2993: 0.187286
# Cost after iteration 2994: 0.187299
# Cost after iteration 2995: 0.187344
# Cost after iteration 2996: 0.187401
# Cost after iteration 2997: 0.187530
# Cost after iteration 2998: 0.187680
# Cost after iteration 2999: 0.188011
# W1 = [[ 1.97400732 -1.68735181]
#  [ 2.21244075 -1.96207282]]
# b1 = [[-4.83489386]
#  [ 6.31854573]]
# W2 = [[-7.25665649  7.11965784]]
# b2 = [[-3.44475406]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.
#
# %%
# 模型的最终参数可以用于预测，同时它可以确定边界线的位置。
# %%

# %% [markdown]
# <a name='ex08'></a>
# #### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.
#
# %%
# 利用前向传播计算预测值，然后使用0.5为阈值进行 0/1 分类。
# %%

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X

    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)

    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """

    ### START CODE HERE ### (≈ 2 lines of code)
    A2, _ = forward_propagation(X, parameters)
    predictions = A2 >= 0.5
    ### END CODE HERE ###

    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).
#
# %%
# 让我们来看看这个边界线。
# 如果你不理解函数`plot_decision_boundary`，请不要担心，它只是对平面上的一些点进行预测，并将它们绘制为等高线图（只有两种颜色-蓝色和红色）。
# %%

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!
#
# %%
# 太棒了，你可以看到，更复杂的分类问题也可以通过两层神经网络来解决！
# %%

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:
#
# %%
# 构建一个略有差异的数据集：
# %%

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:
#
# %%
# 请注意，在构建神经网络时，隐藏层中的一些节点可以作为参数。尝试更改此参数并研究结果：
# %%

# %%
parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %%
parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %%
parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.
#
# %%
# 你可以看到一些错误的分类点。
# 现实世界的数据集通常线性不可分，并且存在一定比例的错误。
# 更重要的是，你不能构建一个过于拟合的模型，几乎完全符合特定数据集是可能无法预测未来其他的观察结果。
# 这个问题被称为**过拟合**。
# %%

# %% [markdown]
# Congrats on finishing this programming assignment!
